# %% [markdown]
# <h1><center>Fine Tuning </center></h1>

# %%
import pandas as pd
import torch
import numpy as np
import re
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from transformers import BertTokenizer, BertModel
from sklearn.preprocessing import StandardScaler
from scipy.stats import randint, uniform
from imblearn.over_sampling import SMOTE
import joblib

# %%
# Load dataset
df = pd.read_csv("dementia_dataset_6.csv")
df['Severity'] = df['Severity'].astype(int)

# %%
# Clean text
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"\s+", " ", text)
    return text.strip()

df["Transcript_CTD"] = df["Transcript_CTD"].fillna("").apply(clean_text)
df["Transcript_PFT"] = df["Transcript_PFT"].fillna("").apply(clean_text)
df["Transcript_SFT"] = df["Transcript_SFT"].fillna("").apply(clean_text)
df['Text'] = df['Transcript_CTD'] + " " + df['Transcript_PFT'] + " " + df['Transcript_SFT']

# %%
# Define all feature columns to include
feature_columns = [
    'TTR', 'Brunet_Index', 'Avg_Word_Length',
    'NOUN_ratio', 'VERB_ratio', 'PRONOUN_ratio',
    'Subordinate_Clauses', 'Parse_Tree_Depth', 'Idea_Density',
    'Key_Elements_Described', 'Irrelevant_Details',
    'Pauses', 'Repair_Rate'
]

# %%
# Split dataset
train_idx, test_idx = train_test_split(df.index, test_size=0.3, random_state=42)
train_labels = df.loc[train_idx, 'Severity']
test_labels = df.loc[test_idx, 'Severity']
train_features = df.loc[train_idx, feature_columns].values
test_features = df.loc[test_idx, feature_columns].values

# %%
# Normalize numeric features
scaler = StandardScaler()
train_features_scaled = scaler.fit_transform(train_features)
test_features_scaled = scaler.transform(test_features)

# %%
joblib.dump(scaler, "speech_scaler.joblib")
# Out:
# ['speech_scaler.joblib']

# %%
# Load BERT
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert_model = BertModel.from_pretrained("bert-base-uncased")

# %%
# Function to extract BERT embeddings in batches
def extract_bert_embeddings(texts, batch_size=16):
    embeddings = []
    for i in range(0, len(texts), batch_size):
        batch_texts = list(texts[i:i+batch_size])
        inputs = tokenizer(batch_texts, return_tensors="pt", truncation=True, padding=True, max_length=256)
        with torch.no_grad():
            outputs = bert_model(**inputs)
        batch_embeddings = outputs.last_hidden_state.mean(dim=1).numpy()
        embeddings.append(batch_embeddings)
    return np.vstack(embeddings)

# %%
# Extract embeddings for each transcript type
ct_emb_train = extract_bert_embeddings(df.loc[train_idx, 'Transcript_CTD'])
pf_emb_train = extract_bert_embeddings(df.loc[train_idx, 'Transcript_PFT'])
sf_emb_train = extract_bert_embeddings(df.loc[train_idx, 'Transcript_SFT'])

ct_emb_test = extract_bert_embeddings(df.loc[test_idx, 'Transcript_CTD'])
pf_emb_test = extract_bert_embeddings(df.loc[test_idx, 'Transcript_PFT'])
sf_emb_test = extract_bert_embeddings(df.loc[test_idx, 'Transcript_SFT'])

# %%
# Combine embeddings and features
train_combined = np.hstack((ct_emb_train, pf_emb_train, sf_emb_train, train_features_scaled))
test_combined = np.hstack((ct_emb_test, pf_emb_test, sf_emb_test, test_features_scaled))

# %%
# Define a function for hyperparameter tuning
def tune_hyperparameters(X_train, y_train):
    model = xgb.XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="mlogloss")
    param_distributions = {
        "n_estimators": randint(50, 600),
        "learning_rate": uniform(0.01, 0.3),
        "max_depth": randint(3, 15),
        "min_child_weight": randint(1, 10),
        "gamma": uniform(0, 2),
        "subsample": uniform(0.5, 1.0),
        "colsample_bytree": uniform(0.5, 1.0),
        "reg_alpha": uniform(0, 5),
        "reg_lambda": uniform(0, 5),
    }
    search = RandomizedSearchCV(
        model,
        param_distributions=param_distributions,
        n_iter=100,
        scoring="accuracy",
        cv=5,
        verbose=1,
        random_state=42,
        n_jobs=-1,
    )
    print("Starting hyperparameter tuning with RandomizedSearchCV...")
    search.fit(X_train, y_train)
    print("Best parameters found from RandomizedSearchCV:", search.best_params_)
    return search.best_estimator_

# %%
# Perform hyperparameter tuning
best_model = tune_hyperparameters(train_combined, train_labels)
# Out:
# Starting hyperparameter tuning with RandomizedSearchCV...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:11:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:12:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:13:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:14:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:15:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:16:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:17:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:18:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:20:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:21:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:22:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:23:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:23:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:23:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:23:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:23:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:24:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 380 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.36618 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.10111 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.11748 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.10754 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.04671 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.07044 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.02083 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.3022 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.29018 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.21324 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.26079 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.44285 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.01879 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.03093 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.48342 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.43673 for Parameter subsample exceed bound [0,1]
# ...
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.03978 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.04285 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.24146 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.26246 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.3268 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.45907 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.43212 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.33749 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.41845 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.08707 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1599, in fit
#     self._Booster = train(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 2100, in update
#     _check_call(
#   File "/home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.05731 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/wathsalya/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.85485164        nan
#         nan        nan        nan        nan        nan        nan
#  0.82488639        nan 0.83875969 0.8503074         nan        nan
#  0.84565624        nan        nan        nan        nan        nan
#         nan 0.82723871 0.84562951 0.8617482         nan        nan
#         nan 0.83643411        nan        nan        nan        nan
#         nan        nan        nan 0.83413526        nan        nan
#         nan        nan        nan 0.82493986 0.82953756        nan
#  0.85025394        nan        nan        nan        nan        nan
#  0.83646084        nan 0.83640738        nan        nan 0.83410853
#         nan        nan        nan 0.84333066        nan        nan
#  0.82951083        nan 0.83643411        nan        nan        nan
#  0.81574445 0.83416199        nan        nan        nan        nan
#  0.85487837        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.85257952
#         nan        nan 0.82951083        nan]
#   warnings.warn(
# /home/wathsalya/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [19:27:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters found from RandomizedSearchCV: {'colsample_bytree': np.float64(0.8500784076946757), 'gamma': np.float64(1.2902067240611297), 'learning_rate': np.float64(0.2106772178989299), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 565, 'reg_alpha': np.float64(0.1215798321572692), 'reg_lambda': np.float64(3.227361479535839), 'subsample': np.float64(0.6771106794070489)}

# %%
def evaluate_model(model, X_test, y_test):
    predictions = model.predict(X_test)
    pred_probabilities = model.predict_proba(X_test)

    # Convert to numpy arrays to ensure consistent handling
    true_labels = np.array(y_test)
    pred_labels = np.array(predictions)

    print("\nEvaluation Results:")
    print(f"Accuracy: {accuracy_score(true_labels, pred_labels):.2f}")
    print(f"Precision: {precision_score(true_labels, pred_labels, average='weighted'):.2f}")
    print(f"Recall: {recall_score(true_labels, pred_labels, average='weighted'):.2f}")
    print(f"F1-Score: {f1_score(true_labels, pred_labels, average='weighted'):.2f}")
    print("\nClassification Report:")
    print(classification_report(true_labels, pred_labels))
    print("\nConfusion Matrix:")
    print(confusion_matrix(true_labels, pred_labels))
    
    # Probability analysis - with fixes
    print("\nProbability Distribution Analysis:")
    
    # Calculate average prediction probability for correct predictions
    correct_indices = pred_labels == true_labels
    if np.any(correct_indices):
        # Fixed: properly extract probabilities for the correct class
        correct_probs = [prob[label] for prob, label in zip(pred_probabilities[correct_indices], true_labels[correct_indices])]
        print(f"Average probability for correct predictions: {np.mean(correct_probs):.4f}")
    
    # Calculate average highest probability for incorrect predictions
    incorrect_indices = ~correct_indices
    if np.any(incorrect_indices):
        incorrect_max_probs = [np.max(prob) for prob in pred_probabilities[incorrect_indices]]
        print(f"Average highest probability for incorrect predictions: {np.mean(incorrect_max_probs):.4f}")
    
    # Find uncertain predictions (highest probability < threshold)
    threshold = 0.7
    uncertain_predictions = [i for i, probs in enumerate(pred_probabilities) 
                           if np.max(probs) < threshold]
    print(f"Number of uncertain predictions (max prob < {threshold}): {len(uncertain_predictions)}")
    
    return pred_labels, pred_probabilities

# %%
# Evaluate the tuned model
predictions, probabilities = evaluate_model(best_model, test_combined, test_labels)
# Out:
# Evaluation Results:
# Accuracy: 0.85
# Precision: 0.84
# Recall: 0.85
# F1-Score: 0.84
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        92
#            1       0.93      0.99      0.96        67
#            2       0.44      0.24      0.31        17
#            3       0.78      0.70      0.74        10
#
#     accuracy                           0.85       186
#    macro avg       0.75      0.70      0.72       186
# weighted avg       0.84      0.85      0.84       186
#
#
# Confusion Matrix:
# [[82  4  4  2]
#  [ 0 66  1  0]
#  [13  0  4  0]
#  [ 2  1  0  7]]
#
# Probability Distribution Analysis:
# Average probability for correct predictions: 0.8687
# Average highest probability for incorrect predictions: 0.7371
# Number of uncertain predictions (max prob < 0.7): 33

# %%
# Optional: Save the probabilities for further analysis
results_df = pd.DataFrame(probabilities)
results_df['true_class'] = test_labels.values
results_df['predicted_class'] = predictions
results_df.to_csv('prediction_probabilities_speech.csv', index=False)
print("Detailed probability data saved to 'prediction_probabilities_speech.csv'")
# Out:
# Detailed probability data saved to 'prediction_probabilities_speech.csv'

# %%
# Save using joblib (better for large NumPy arrays, slightly faster)
joblib.dump(best_model, 'best_model_speech.joblib')
print("Model saved to 'best_model_speech.joblib' using joblib")
# Out:
# Model saved to 'best_model_speech.joblib' using joblib
